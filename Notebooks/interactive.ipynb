# %%
import sys
from pathlib import Path
 
root = Path.cwd().resolve().parent
sys.path.insert(0, str(root))
 
import utilities.state_selector_interactive as state_selector
import utilities.algorithm_interactive as algorithm_selector

# %%
state_selector.show()
# Out:
# VBox(children=(HBox(children=(VBox(children=(IntSlider(value=50, description='Fock cutoff:', min=10), Dropdown…

# %%
state_selector.state()
algorithm_selector.show()
# Out:
# VBox(children=(HTML(value='<h3>Sampling Parameters</h3>'), VBox(children=(HTML(value='<i>x range: [-5.0, 5.0],…
